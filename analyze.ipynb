# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("../result.csv", sep=";", header=None)
df.sort_values(by=df.columns[0], ascending = False)
# Out:
#            0       1      2         3         4         5         6   \
# 16951  209.79  2202.8  10.50  moonfire  moonfire  starfall  starfall
# 22471  193.27  2222.6  11.50     wrath     wrath  moonfire  moonfire
# 38715  190.58  2096.4  11.00     wrath  moonfire  moonfire     wrath
# 63377  181.05  1901.0  10.50     wrath  moonfire     wrath  moonfire
# 81110  156.43  2033.6  13.00  moonfire     wrath     wrath     wrath
# ...       ...     ...    ...       ...       ...       ...       ...
# 91022   23.98  1515.8  63.20  moonfire  moonfire  moonfire  starfall
# 99426   23.84  1414.8  59.34  moonfire  starfall  moonfire  moonfire
# 36470   23.57  1524.8  64.70  starfall  moonfire     wrath  moonfire
# 74292   23.06  1476.6  64.04  moonfire  moonfire  moonfire  starfall
# 51873   21.47  1335.2  62.20  starfall  moonfire  moonfire  moonfire
#
#              7         8         9         10        11        12        13  \
# 16951  starfall  moonfire     wrath  starfall  starfall  moonfire  moonfire
# 22471  starfall  starfall  starfall  starfall     wrath  starfall  starfall
# 38715  moonfire  moonfire  starfall     wrath  moonfire     wrath  moonfire
# 63377     wrath  moonfire     wrath  moonfire  moonfire  moonfire     wrath
# 81110  moonfire  starfall     wrath     wrath  moonfire  moonfire  starfall
# ...         ...       ...       ...       ...       ...       ...       ...
# 91022  moonfire  starfall  moonfire  moonfire     wrath     wrath  moonfire
# 99426     wrath  moonfire     wrath  moonfire     wrath  starfall  moonfire
# 36470  starfall  moonfire  moonfire  moonfire  moonfire  moonfire  moonfire
# 74292     wrath  moonfire  starfall  moonfire  moonfire  moonfire     wrath
# 51873  moonfire  moonfire  moonfire  moonfire  moonfire  moonfire  moonfire
#
#              14        15        16        17        18        19        20  \
# 16951     wrath  starfall     wrath     wrath  starfall  starfall     wrath
# 22471  moonfire  starfall  starfall  starfall     wrath  starfall     wrath
# 38715  starfall  starfall     wrath     wrath  starfall  starfall     wrath
# 63377  moonfire  starfall  starfall     wrath  starfall  starfall     wrath
# 81110     wrath     wrath  starfall  starfall     wrath     wrath  starfall
# ...         ...       ...       ...       ...       ...       ...       ...
# 91022     wrath  moonfire  moonfire     wrath     wrath     wrath     wrath
# 99426  moonfire  moonfire  moonfire     wrath  moonfire  moonfire  moonfire
# 36470  moonfire  moonfire     wrath  moonfire     wrath  moonfire  moonfire
# 74292  moonfire     wrath  moonfire  moonfire  starfall     wrath  moonfire
# 51873     wrath  moonfire     wrath     wrath  moonfire     wrath  moonfire
#
#              21        22        23        24        25        26        27  \
# 16951  starfall     wrath  starfall  moonfire     wrath     wrath  moonfire
# 22471     wrath  starfall  starfall     wrath  starfall  moonfire     wrath
# 38715     wrath  starfall     wrath     wrath     wrath  starfall     wrath
# 63377     wrath  starfall     wrath     wrath  moonfire  starfall     wrath
# 81110  starfall     wrath  moonfire  starfall     wrath  moonfire     wrath
# ...         ...       ...       ...       ...       ...       ...       ...
# 91022  moonfire  moonfire  moonfire  moonfire  moonfire     wrath  moonfire
# 99426  moonfire  moonfire  moonfire  moonfire  moonfire  moonfire     wrath
# 36470  starfall     wrath     wrath  moonfire  starfall  moonfire  moonfire
# 74292  moonfire  starfall  moonfire  moonfire  moonfire  moonfire  moonfire
# 51873     wrath  moonfire  moonfire  moonfire     wrath  moonfire  moonfire
#
#              28        29        30        31        32
# 16951     wrath  moonfire     wrath     wrath  starfall
# 22471     wrath     wrath     wrath  starfall  starfall
# 38715     wrath     wrath     wrath     wrath  starfall
# 63377     wrath  starfall     wrath  starfall     wrath
# 81110  moonfire  starfall  moonfire     wrath     wrath
# ...         ...       ...       ...       ...       ...
# 91022  moonfire  starfall  moonfire  moonfire  moonfire
# 99426  starfall  moonfire  starfall  moonfire  moonfire
# 36470  moonfire  starfall  starfall  moonfire  moonfire
# 74292  moonfire  starfall  moonfire  moonfire  moonfire
# 51873  moonfire  moonfire  moonfire     wrath  moonfire
#
# [100000 rows x 33 columns]

# %%
df.head(100)
# Out:
#        0      1      2         3         4         5         6         7   \
# 0   23.37  701.0  30.00  starfall  moonfire  moonfire  starfall     wrath
# 1   23.95  718.4  30.00  starfall  starfall  moonfire  starfall  starfall
# 2   25.85  850.0  32.88     wrath  starfall     wrath  starfall  starfall
# 3   27.91  725.6  26.00  starfall  moonfire     wrath  moonfire  moonfire
# 4   25.32  785.8  31.04     wrath  starfall     wrath     wrath     wrath
# ..    ...    ...    ...       ...       ...       ...       ...       ...
# 95  29.23  716.2  24.50  moonfire  moonfire     wrath  starfall     wrath
# 96  20.37  556.8  27.34     wrath     wrath  moonfire  moonfire     wrath
# 97  20.42  678.0  33.20  starfall  moonfire  moonfire  starfall  moonfire
# 98  37.77  837.8  22.18     wrath     wrath  starfall     wrath  starfall
# 99  31.45  866.2  27.54     wrath     wrath  moonfire     wrath  starfall
#
#           8         9         10        11        12
# 0   moonfire  starfall  starfall  starfall  moonfire
# 1      wrath  moonfire  moonfire  starfall  moonfire
# 2      wrath     wrath     wrath  moonfire  moonfire
# 3      wrath  moonfire  starfall     wrath     wrath
# 4   moonfire  starfall     wrath  moonfire  starfall
# ..       ...       ...       ...       ...       ...
# 95     wrath  starfall     wrath     wrath  starfall
# 96  moonfire     wrath  starfall  starfall     wrath
# 97  starfall  moonfire  moonfire     wrath  moonfire
# 98  moonfire     wrath  starfall     wrath     wrath
# 99     wrath  moonfire     wrath  starfall  starfall
#
# [100 rows x 13 columns]
